# %% [markdown]
# # Exploratory Data Analysis - Terrorism

# %% [markdown]
# ## Aim

# %% [markdown]
# * **The goal of this project is to perform Exploratory Data Analysis (EDA) on the terrorism dataset
#     to extract meaningful insights and patterns. By analyzing the dataset, we aim to uncover
#     trends, identify high-risk regions, understand attack characteristics, and potentially reveal
#     factors that contribute to terrorist activities.**

# %% [markdown]
# ## Project done by
#
# * **Jokin Prabhu**

# %% [markdown]
# ## Data Set
# * **i have download the dataset from the kaggle website.
#      https://www.kaggle.com/datasets/START-UMD/gtd?select=globalterrorismdb_0718dist.csv**

# %% [markdown]
# ## Technologies Used
#
# *  **Python**
# *  **Numpy**
# *  **Pandas**
# *  **Matplotlib**
# *  **Seaborn**
# *  **Plotly**
# *  **Jupyter Notebok**
# *  **Kaggle**
# *  **Statistics**

# %% [markdown]
# ## Introduction

# %% [markdown]
# * **Terrorism remains a pressing global concern, with its devastating impacts reverberating across societies and nations. To effectively combat this threat and develop strategies for prevention, it is crucial to gain a comprehensive understanding of the patterns and dynamics underlying terrorist activities. Exploratory Data Analysis (EDA) plays a pivotal role in this endeavor, offering a lens through which we can delve deep into the terrorism dataset to extract valuable insights.**
#
# * **The primary objective of this project is to harness the power of EDA to unravel the intricate web of information encapsulated within the dataset. Through systematic examination and analysis, we aspire to shed light on critical aspects of terrorism, such as its geographical hotspots, the evolution of attack methods, and potential drivers fueling these acts of violence. By mining this data, we aim to empower decision-makers, policymakers, and researchers with the knowledge needed to formulate informed strategies to counteract and mitigate the threat of terrorism.**
#
# * **In this journey of data exploration, we will navigate through the rich dataset, conduct statistical analyses, visualize trends, and uncover hidden correlations. Our ultimate goal is to not only understand the past and present but also to glean insights that can shape a safer and more secure future for societies worldwide.**

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_path ='Terrorism.jpg'

# Read and display the image
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis labels and ticks
plt.show()

# %% [markdown]
# # DATASET OVERVIEW

# %%
# import the required library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the dataset.
df = pd.read_csv("C:\\Users\\Ragu.M\\Terrorism\\Terrorism.csv", encoding='ISO-8859-1')
df.head()
# Out:
# C:\Users\Ragu.M\AppData\Local\Temp\ipykernel_10060\4159272081.py:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:\\Users\\Ragu.M\\Terrorism\\Terrorism.csv", encoding='ISO-8859-1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
# number of rows and columns in the datatset.
df.shape
# Out:
# (181691, 135)

# %%
# names of all the columns.
for n in df.columns:
    print(n)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# weaptype1_txt
# weapsubtype1
# weapsubtype1_txt
# weaptype2
# weaptype2_txt
# weapsubtype2
# weapsubtype2_txt
# weaptype3
# weaptype3_txt
# weapsubtype3
# weapsubtype3_txt
# weaptype4
# weaptype4_txt
# weapsubtype4
# weapsubtype4_txt
# weapdetail
# nkill
# nkillus
# nkillter
# nwound
# nwoundus
# nwoundte
# property
# propextent
# propextent_txt
# propvalue
# propcomment
# ishostkid
# nhostkid
# nhostkidus
# nhours
# ndays
# divert
# kidhijcountry
# ransom
# ransomamt
# ransomamtus
# ransompaid
# ransompaidus
# ransomnote
# hostkidoutcome
# hostkidoutcome_txt
# nreleased
# addnotes
# scite1
# scite2
# scite3
# dbsource
# INT_LOG
# INT_IDEO
# INT_MISC
# INT_ANY
# related

# %%
# datatypes of all the columns.
df.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
# general inforamtion about the columns.
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# # DATA CLEANING

# %%
# extract only required columns from the original dataset.
df=df[['iyear','country_txt','region_txt','city','attacktype1_txt','targtype1_txt','gname','nkill']]
df.head()
# Out:
#    iyear         country_txt                   region_txt           city  \
# 0   1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1   1970              Mexico                North America    Mexico city
# 2   1970         Philippines               Southeast Asia        Unknown
# 3   1970              Greece               Western Europe         Athens
# 4   1970               Japan                    East Asia        Fukouka
#
#                   attacktype1_txt                targtype1_txt  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                                 gname  nkill
# 0                              MANO-D    1.0
# 1  23rd of September Communist League    0.0
# 2                             Unknown    1.0
# 3                             Unknown    NaN
# 4                             Unknown    NaN

# %%
# name of all the columns.
for n in df.columns:
    print(n)
# Out:
# iyear
# country_txt
# region_txt
# city
# attacktype1_txt
# targtype1_txt
# gname
# nkill

# %%
# change the name of the columns.
df.rename(columns = {'iyear':'year', 'country_txt':'country','region_txt':'region','attacktype1_txt':'attacktype','targtype1_txt':'target','gname':'organization','nkill':'killed'}, inplace = True)

# %%
# head of the dataset.
df.head()
# Out:
#    year             country                       region           city  \
# 0  1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1  1970              Mexico                North America    Mexico city
# 2  1970         Philippines               Southeast Asia        Unknown
# 3  1970              Greece               Western Europe         Athens
# 4  1970               Japan                    East Asia        Fukouka
#
#                        attacktype                       target  \
# 0                   Assassination  Private Citizens & Property
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                   Assassination          Journalists & Media
# 3               Bombing/Explosion      Government (Diplomatic)
# 4  Facility/Infrastructure Attack      Government (Diplomatic)
#
#                          organization  killed
# 0                              MANO-D     1.0
# 1  23rd of September Communist League     0.0
# 2                             Unknown     1.0
# 3                             Unknown     NaN
# 4                             Unknown     NaN

# %%
# sum of all null values in the columns.
df.isnull().sum()
# Out:
# year                0
# country             0
# region              0
# city              434
# attacktype          0
# target              0
# organization        0
# killed          10313
# dtype: int64

# %%
# drop all rows which have null values.
df = df.dropna()

# %%
# head of the dataset.
df.head()
# Out:
#    year             country                       region           city  \
# 0  1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1  1970              Mexico                North America    Mexico city
# 2  1970         Philippines               Southeast Asia        Unknown
# 5  1970       United States                North America          Cairo
# 6  1970             Uruguay                South America     Montevideo
#
#                     attacktype                       target  \
# 0                Assassination  Private Citizens & Property
# 1  Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                Assassination          Journalists & Media
# 5                Armed Assault                       Police
# 6                Assassination                       Police
#
#                          organization  killed
# 0                              MANO-D     1.0
# 1  23rd of September Communist League     0.0
# 2                             Unknown     1.0
# 5                  Black Nationalists     0.0
# 6                 Tupamaros (Uruguay)     0.0

# %%
# sum of all null values in the columns.
df.isnull().sum()
# Out:
# year            0
# country         0
# region          0
# city            0
# attacktype      0
# target          0
# organization    0
# killed          0
# dtype: int64

# %%
# datatype of all the columns.
df.dtypes
# Out:
# year              int64
# country          object
# region           object
# city             object
# attacktype       object
# target           object
# organization     object
# killed          float64
# dtype: object

# %%
# sort the dataset in descending order of the killed column.
df.sort_values(by=['killed'],ascending=False).head(10)
# Out:
#         year        country                      region              city  \
# 133518  2014           Iraq  Middle East & North Africa            Tikrit
# 73126   2001  United States               North America     New York City
# 73127   2001  United States               North America     New York City
# 55934   1994         Rwanda          Sub-Saharan Africa            Gikoro
# 136283  2014           Iraq  Middle East & North Africa            Sinjar
# 133225  2014           Iraq  Middle East & North Africa            Badush
# 179671  2017        Somalia          Sub-Saharan Africa         Mogadishu
# 76347   2004          Nepal                  South Asia  Dhading district
# 136746  2014          Syria  Middle East & North Africa           Unknown
# 170198  2016          Syria  Middle East & North Africa           Palmyra
#
#                          attacktype                       target  \
# 133518  Hostage Taking (Kidnapping)                     Military
# 73126                     Hijacking  Private Citizens & Property
# 73127                     Hijacking  Private Citizens & Property
# 55934                 Armed Assault  Private Citizens & Property
# 136283  Hostage Taking (Kidnapping)  Private Citizens & Property
# 133225                Armed Assault                       Police
# 179671            Bombing/Explosion                     Business
# 76347                 Armed Assault         Government (General)
# 136746  Hostage Taking (Kidnapping)                     Military
# 170198  Hostage Taking (Kidnapping)  Private Citizens & Property
#
#                                        organization  killed
# 133518  Islamic State of Iraq and the Levant (ISIL)  1570.0
# 73126                                      Al-Qaida  1384.0
# 73127                                      Al-Qaida  1383.0
# 55934                               Hutu extremists  1180.0
# 136283  Islamic State of Iraq and the Levant (ISIL)   953.0
# 133225  Islamic State of Iraq and the Levant (ISIL)   670.0
# 179671                                   Al-Shabaab   588.0
# 76347      Communist Party of Nepal- Maoist (CPN-M)   518.0
# 136746  Islamic State of Iraq and the Levant (ISIL)   517.0
# 170198  Islamic State of Iraq and the Levant (ISIL)   433.0

# %%
# change datatype of killed column from float to int.
df=df.astype({'killed':'int'})

# %%
# datatypes of all the columns.
df.dtypes
# Out:
# year             int64
# country         object
# region          object
# city            object
# attacktype      object
# target          object
# organization    object
# killed           int32
# dtype: object

# %%
# head of the dataset.
df.head()
# Out:
#    year             country                       region           city  \
# 0  1970  Dominican Republic  Central America & Caribbean  Santo Domingo
# 1  1970              Mexico                North America    Mexico city
# 2  1970         Philippines               Southeast Asia        Unknown
# 5  1970       United States                North America          Cairo
# 6  1970             Uruguay                South America     Montevideo
#
#                     attacktype                       target  \
# 0                Assassination  Private Citizens & Property
# 1  Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                Assassination          Journalists & Media
# 5                Armed Assault                       Police
# 6                Assassination                       Police
#
#                          organization  killed
# 0                              MANO-D       1
# 1  23rd of September Communist League       0
# 2                             Unknown       1
# 5                  Black Nationalists       0
# 6                 Tupamaros (Uruguay)       0

# %%
# number of rows and columns in the dataset.
df.shape
# Out:
# (170944, 8)

# %%
# basic information about the dataset.
df.describe()
# Out:
#                 year         killed
# count  170944.000000  170944.000000
# mean     2003.066525       2.406010
# std        12.956611      11.559809
# min      1970.000000       0.000000
# 25%      1991.000000       0.000000
# 50%      2009.000000       0.000000
# 75%      2014.000000       2.000000
# max      2017.000000    1570.000000

# %% [markdown]
# # Number Of Terrorist Activities Each Year

# %%
# year wise terrorist attack.
plt.subplots(figsize=(25,8))
sns.countplot(x='year', data=df,ec='black')
plt.xticks(rotation=90)
plt.xlabel("Year",fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.grid(True)
plt.show()

# %% [markdown]
# From the above we can say that, 2014 was the deadliest year, where the maximum number of attacks takes place.

# %% [markdown]
# # Terrorist Activities by Region in each Year

# %%
# extract year column of the dataset.
df.year
# Out:
# 0         1970
# 1         1970
# 2         1970
# 5         1970
# 6         1970
#           ...
# 181686    2017
# 181687    2017
# 181688    2017
# 181689    2017
# 181690    2017
# Name: year, Length: 170943, dtype: int64

# %%
# extract region column of the datatset.
df.region
# Out:
# 0         Central America & Caribbean
# 1                       North America
# 2                      Southeast Asia
# 5                       North America
# 6                       South America
#                      ...
# 181686             Sub-Saharan Africa
# 181687     Middle East & North Africa
# 181688                 Southeast Asia
# 181689                     South Asia
# 181690                 Southeast Asia
# Name: region, Length: 170943, dtype: object

# %%
# region wise and year wise terrorist attcks visualization.
pd.crosstab(df.year,df.region).plot(kind='area',figsize=(20,6))
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Terrorist Activities by Region in each Year')
plt.grid(True)
plt.show()

# %% [markdown]
# * **From the above we can say that, after 2010 there is huge growth in the terrorist attacks in almost all regions of the world.**

# %%
# create a dataset r_type.
r_type=df.region.value_counts().to_frame().reset_index()
r_type
# Out:
#                           index  region
# 0    Middle East & North Africa   48171
# 1                    South Asia   43887
# 2                 South America   17306
# 3            Sub-Saharan Africa   15937
# 4                Western Europe   15727
# 5                Southeast Asia   11961
# 6   Central America & Caribbean    8022
# 7                Eastern Europe    4973
# 8                 North America    3362
# 9                     East Asia     763
# 10                 Central Asia     558
# 11        Australasia & Oceania     276

# %%
# change the name of the columns of the d_type dataset.
r_type.columns=['region_name','count']

# %%
# dataset r_type.
r_type
# Out:
#                     region_name  count
# 0    Middle East & North Africa  48171
# 1                    South Asia  43887
# 2                 South America  17306
# 3            Sub-Saharan Africa  15937
# 4                Western Europe  15727
# 5                Southeast Asia  11961
# 6   Central America & Caribbean   8022
# 7                Eastern Europe   4973
# 8                 North America   3362
# 9                     East Asia    763
# 10                 Central Asia    558
# 11        Australasia & Oceania    276

# %%
# total number of terrorist attacks in various regions of the world.
sns.barplot(y='region_name',x='count',data=r_type,orient='h',palette='flare',ec='black')
plt.grid(True)
plt.title("Number of Total Attacks in Each Region")
plt.ylabel('Region')
plt.xlabel('Number of attacks')
plt.show()

# %% [markdown]
# * **From the above we can say that, Middle East & North Africa and South Asia has the highest number of attacks among all regions in the world.**

# %% [markdown]
# # Total number of attacks of each country

# %%
# create a datset top_1o_country.
top_10_country=df.country.value_counts()[:10].to_frame().reset_index()
top_10_country
# Out:
#             index  country
# 0            Iraq    23895
# 1        Pakistan    14108
# 2     Afghanistan    12223
# 3           India    11740
# 4        Colombia     7848
# 5     Philippines     6694
# 6            Peru     5457
# 7  United Kingdom     5065
# 8          Turkey     4160
# 9     El Salvador     3939

# %%
# change the name of the column of the dataset.
top_10_country.columns=['country_name','count']

# %%
# dataset top_10_country.
top_10_country
# Out:
#      country_name  count
# 0            Iraq  23895
# 1        Pakistan  14108
# 2     Afghanistan  12223
# 3           India  11740
# 4        Colombia   7848
# 5     Philippines   6694
# 6            Peru   5457
# 7  United Kingdom   5065
# 8          Turkey   4160
# 9     El Salvador   3939

# %%
# bar-plot for top 10 countries which are most affected by terrorism.
plt.figure(figsize=(15,5))
sns.barplot(data=top_10_country,x='country_name',y='count',ec='black',lw=1)
plt.grid(True)
plt.title('Top 10 Countries with most Attacks',fontsize=20)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.show()

# %% [markdown]
# * **From the above we can say that, Iraq is the most affected country from the terrorism.**

# %% [markdown]
# # Target Methods by Terrorists

# %%
# create a dataframe t_type.
t_type=df.attacktype.value_counts()[0:10].to_frame().reset_index()
t_type
# Out:
#                                  index  attacktype
# 0                    Bombing/Explosion       84199
# 1                        Armed Assault       40129
# 2                        Assassination       19206
# 3       Facility/Infrastructure Attack        9774
# 4          Hostage Taking (Kidnapping)        8585
# 5                              Unknown        6549
# 6                      Unarmed Assault         998
# 7  Hostage Taking (Barricade Incident)         898
# 8                            Hijacking         605

# %%
# change the column name of the t_type dataset.
t_type.columns=['target_type','count']

# %%
# datatset t_type.
t_type
# Out:
#                            target_type  count
# 0                    Bombing/Explosion  84199
# 1                        Armed Assault  40129
# 2                        Assassination  19206
# 3       Facility/Infrastructure Attack   9774
# 4          Hostage Taking (Kidnapping)   8585
# 5                              Unknown   6549
# 6                      Unarmed Assault    998
# 7  Hostage Taking (Barricade Incident)    898
# 8                            Hijacking    605

# %%
# bar-plot to show which method is most used by terrorist to attack.
plt.figure(figsize=(25,10))
sns.barplot(x='target_type',y='count',data=t_type,palette='coolwarm',ec='black')
plt.xlabel('Target Type',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.title("Target Method by Terrorists",fontsize=30)
plt.grid(True)

# %% [markdown]
# * **From the above we can say that, terrorist used Bombing/Explosion as a target method most number of times.**

# %% [markdown]
# # Most active terrorist group in the world

# %%
# create a dataset g_type.
g_type = df.organization.value_counts()[:5].to_frame().reset_index()
g_type
# Out:
#                                          index  organization
# 0                                      Unknown         79199
# 1                                      Taliban          7125
# 2  Islamic State of Iraq and the Levant (ISIL)          5066
# 3                            Shining Path (SL)          4078
# 4                      New People's Army (NPA)          2693

# %%
# change the name of the column of the g_type dataset.
g_type.columns=['organization_name','count']

# %%
# dataset g_type.
g_type
# Out:
#                              organization_name  count
# 0                                      Unknown  79199
# 1                                      Taliban   7125
# 2  Islamic State of Iraq and the Levant (ISIL)   5066
# 3                            Shining Path (SL)   4078
# 4                      New People's Army (NPA)   2693

# %%
# bar-plot for the most active terrorist organization in the world.
plt.figure(figsize=(20,7))
sns.barplot(x='organization_name',y='count',data=g_type,ec='black',palette='flare')
plt.title('Most Active Terrorist Organization in the World',fontsize=20)
plt.xlabel('Organization Name',fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.grid(True)

# %% [markdown]
# * **From the above we can say that, Taliban is the most active terrorist organization in the world.**

# %% [markdown]
# # Number of Total Casualities in Each Country

# %%
# create a dataset top10_c.
top10_c=df.groupby('country').killed.sum().to_frame().reset_index().sort_values('killed',ascending=False)[0:10]
top10_c
# Out:
#          country  killed
# 81          Iraq   78567
# 0    Afghanistan   39137
# 131     Pakistan   23811
# 127      Nigeria   22682
# 77         India   19341
# 164    Sri Lanka   15530
# 172        Syria   15205
# 33      Colombia   14698
# 136         Peru   12771
# 50   El Salvador   12053

# %%
# bar-plot for top 10 countries where most number of people killed from the terrorism.
plt.figure(figsize=(10,5))
sns.barplot(y='killed',x='country',data=top10_c,ec='black')
plt.xlabel('Name of the Country')
plt.ylabel('Number of people Killed')
plt.grid(True)
plt.show(True)

# %% [markdown]
# * **From the above we can say that, Iraq is that country where terrorists killed most number of people.**

# %% [markdown]
# # City where terrorist killed most number of people in the world ?

# %%
# create a dataset top10_city.
top10_city=df.city.value_counts().to_frame()[0:10].reset_index()
top10_city
# Out:
#           index  city
# 0       Unknown  8986
# 1       Baghdad  7497
# 2       Karachi  2635
# 3         Mosul  2165
# 4          Lima  2132
# 5       Belfast  2129
# 6     Mogadishu  1438
# 7      Santiago  1357
# 8  San Salvador  1263
# 9      Istanbul  1016

# %%
# rename the name of the column of the dataset.
top10_city.columns=['city','count']

# %%
# dataset top10_city.
top10_city
# Out:
#            city  count
# 0       Unknown   8986
# 1       Baghdad   7497
# 2       Karachi   2635
# 3         Mosul   2165
# 4          Lima   2132
# 5       Belfast   2129
# 6     Mogadishu   1438
# 7      Santiago   1357
# 8  San Salvador   1263
# 9      Istanbul   1016

# %%
# Bar-plot for top 10 most affected city from terrorism in the world.
plt.figure(figsize=(12,5))
sns.barplot(x='city',y='count',data=top10_city,ec='black',palette='Set3')
plt.title("Most affected City in the World",fontsize=15)
plt.xlabel('Name of the City',fontsize=12)
plt.ylabel("Number of the Attacks",fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# * **From the above we can say that, Baghdad is the most affected city in the world from terrorism.**

# %% [markdown]
# # Target of the terrorists

# %%
# value counts of the target column of the dataset.
df['target'].value_counts().head()
# Out:
# Private Citizens & Property    40884
# Military                       25622
# Police                         23713
# Government (General)           20282
# Business                       19142
# Name: target, dtype: int64

# %%
# count of top 5 targets.
list(df['target'].value_counts().head())
# Out:
# [40884, 25622, 23713, 20282, 19142]

# %%
# list of the top 5 target of the terrorists.
list(df['target'].value_counts().head().keys())
# Out:
# ['Private Citizens & Property',
#  'Military',
#  'Police',
#  'Government (General)',
#  'Business']

# %%
# Bar-plot of top 5 targets of the terrorists.
plt.figure(figsize=(10,5))
col=['red','yellow','green','black','pink','orange']
plt.bar(list(df['target'].value_counts().head().keys()),list(df['target'].value_counts().head()),color=col,ec='black')
plt.grid(True)
plt.xlabel('Name of the Target',fontsize=11)
plt.ylabel('Number of Attacks',fontsize=11)
plt.show()

# %% [markdown]
# * **From the above we can say that, terrorists target Private Citizens & Property maximum number of times.**

# %% [markdown]
# # Deadliest year in terms of death of people by terrorism

# %%
# create a year dataset.
year=(df.groupby(['year'])['killed'].size()).reset_index()
year
# Out:
#     year  killed
# 0   1970     609
# 1   1971     407
# 2   1972     524
# 3   1973     424
# 4   1974     523
# 5   1975     587
# 6   1976     814
# 7   1977    1189
# 8   1978    1373
# 9   1979    2257
# 10  1980    2211
# 11  1981    1928
# 12  1982    1742
# 13  1983    1974
# 14  1984    2805
# 15  1985    2475
# 16  1986    2481
# 17  1987    3089
# 18  1988    3689
# 19  1989    4290
# 20  1990    3881
# 21  1991    4579
# 22  1992    5048
# 23  1994    3368
# 24  1995    3076
# 25  1996    3001
# 26  1997    3130
# 27  1998     871
# 28  1999    1345
# 29  2000    1757
# 30  2001    1885
# 31  2002    1321
# 32  2003    1258
# 33  2004    1151
# 34  2005    1999
# 35  2006    2619
# 36  2007    3171
# 37  2008    4649
# 38  2009    4551
# 39  2010    4757
# 40  2011    5002
# 41  2012    8314
# 42  2013   11685
# 43  2014   15881
# 44  2015   14160
# 45  2016   12809
# 46  2017   10285

# %%
# sort the year dataset in descending order of the killed colum.
year=year.sort_values(by=['killed'],ascending=False).head()
year
# Out:
#     year  killed
# 43  2014   15881
# 44  2015   14160
# 45  2016   12809
# 42  2013   11685
# 46  2017   10285

# %%
# list of the top 5 years where maximum people killed by terrorism.
list(year['year'])
# Out:
# [2014, 2015, 2016, 2013, 2017]

# %%
# count of the killed in the top 5 year.
list(year['killed'])
# Out:
# [15881, 14160, 12809, 11685, 10285]

# %%
# bar-plot for top 5 years where maximum number of people killed by terrorism.
plt.figure(figsize=(10,5))
color=['red','orange','pink','blue','yellow']
plt.bar(list(year['year']),list(year['killed']),color=color,ec='black')
plt.grid(True)
plt.xlabel('Name of the Year')
plt.ylabel('Number of People Killed')
plt.show()

# %% [markdown]
# * **From the above we can say that, year 2014 is the deadliest year in the history of terrorism. About 16000 people died in the single year by terrorism.**

# %% [markdown]
# ## Conclusion

# %% [markdown]
# * **Exploratory Data Analysis has been a pivotal tool in our quest to fathom the complex landscape of terrorism. As we conclude this project, we reflect upon the wealth of insights we have uncovered and the patterns we have discerned within the dataset. Our analyses have illuminated the geographical regions most affected by terrorist activities, allowing us to identify high-risk areas that demand focused attention and resources.**
#
# * **Furthermore, we have delved into the evolving tactics employed by terrorists, enabling us to anticipate potential future threats and adapt counterterrorism strategies accordingly. By exploring various factors that contribute to acts of terrorism, we have gained a deeper understanding of the drivers behind these acts, a critical step towards addressing root causes.**
#
# * **It is imperative to acknowledge that the fight against terrorism is ongoing and multifaceted. While our EDA has provided invaluable insights, there is still much work to be done. We encourage further research, collaboration, and the application of advanced analytical techniques to continue the pursuit of a safer world.**
#
# * **In conclusion, this project underscores the importance of data-driven approaches in tackling global challenges. By leveraging the power of data and EDA, we are better equipped to comprehend the intricate dynamics of terrorism and work towards a future free from the shadow of violence and fear.**
